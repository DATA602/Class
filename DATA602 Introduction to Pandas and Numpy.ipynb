# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
dframe=pd.read_csv('lec25.csv')

# %%
dframe
# Out:
#    q  r  s  t   apple
# 0  2  3  4  5    pear
# 1  a  s  d  f  rabbit
# 2  5  2  5  7     dog

# %%
dframe=pd.read_csv('lec25.csv', header=None)

# %%
dframe
# Out:
#    0  1  2  3       4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit
# 3  5  2  5  7     dog

# %%
dframe=pd.read_table('lec25.csv', sep=',', header=None)

# %%
dframe
# Out:
#                 0
# 0   q,r,s,t,apple
# 1    2,3,4,5,pear
# 2  a,s,d,f,rabbit
# 3     5,2,5,7,dog

# %%
dframe1=pd.read_csv('lec25.csv', sep=',', header=None, nrows=3)

# %%
dframe1
# Out:
#    0  1  2  3       4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit

# %%
dframe.to_csv('mytextdata_out.csv')

# %%
import sys

# %%
dframe.to_csv(sys.stdout)
# Out:
# ,0,1,2,3,4
# 0,q,r,s,t,apple
# 1,2,3,4,5,pear
# 2,a,s,d,f,rabbit

# %%
dframe.to_csv(sys.stdout, sep='_')
# Out:
# _0_1_2_3_4
# 0_q_r_s_t_apple
# 1_2_3_4_5_pear
# 2_a_s_d_f_rabbit
