# %%
from IPython.display import Image
Image(filename='/Users/tonydiana/Downloads/fighter_jet.jpg')

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
# The ResNet50 pre-trained CNN expects inputs of 24X224 resolution and will classify objects into one of 1,000 possible categories.
img_path='/Users/tonydiana/Downloads/fighter_jet.jpg'
img=image.load_img(img_path, target_size= (224,224))
x= image.img_to_array(img)
x= np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
# Let us Load the model
model=ResNet50(weights='imagenet')
# Out:
# ...
# 102973440/102967424 [==============================] - 11s 0us/step

# %%
preds=model.predict(x)
# Decode the results into a list of tuples
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04552348', 'warplane', 0.729121), ('n04592741', 'wing', 0.11969243), ('n03000684', 'chain_saw', 0.06772807)]

# %%
from IPython.display import Image
Image(filename='/Users/tonydiana/Downloads/fighter_jet.jpg')

# %%
def classify(img_path):
    display(Image(filename=img_path))
    img= image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x,axis=0)
    x = preprocess_input(x)
    preds= model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
classify('/Users/tonydiana/Downloads/fighter_jet.jpg')
# Out:
# Predicted: [('n04552348', 'warplane', 0.729121), ('n04592741', 'wing', 0.11969243), ('n03000684', 'chain_saw', 0.06772807)]

# %%
from IPython.display import Image
Image(filename='/Users/tonydiana/Downloads/car.jpg')

# %%
classify('/Users/tonydiana/Downloads/car.jpg')
# Out:
# Predicted: [('n04285008', 'sports_car', 0.8868446), ('n02974003', 'car_wheel', 0.03519739), ('n03459775', 'grille', 0.026362227)]
