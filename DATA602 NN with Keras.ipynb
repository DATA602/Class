# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('d:/machine learning/pima_indian_data.csv')

# %%
dataset.head(2)
# Out:
#    Number  of times pregnant  Plasma glucose  Diastolic blood pressure  \
# 0                          6             148                        72
# 1                          1              85                        66
#
#    Triceps skinfold thickness  serum insulin  Body mass index  \
# 0                          35              0             33.6
# 1                          29              0             26.6
#
#    Diabetes pedigree function  Age  Class
# 0                       0.627   50      1
# 1                       0.351   31      0

# %%
dataset.describe(include='all')
# Out:
#        Number  of times pregnant  Plasma glucose  Diastolic blood pressure  \
# count                 768.000000      768.000000                768.000000
# mean                    3.845052      120.894531                 69.105469
# std                     3.369578       31.972618                 19.355807
# min                     0.000000        0.000000                  0.000000
# 25%                     1.000000       99.000000                 62.000000
# 50%                     3.000000      117.000000                 72.000000
# 75%                     6.000000      140.250000                 80.000000
# max                    17.000000      199.000000                122.000000
#
#        Triceps skinfold thickness  serum insulin  Body mass index  \
# count                  768.000000     768.000000       768.000000
# mean                    20.536458      79.799479        31.992578
# std                     15.952218     115.244002         7.884160
# min                      0.000000       0.000000         0.000000
# 25%                      0.000000       0.000000        27.300000
# 50%                     23.000000      30.500000        32.000000
# 75%                     32.000000     127.250000        36.600000
# max                     99.000000     846.000000        67.100000
#
#        Diabetes pedigree function         Age       Class
# count                  768.000000  768.000000  768.000000
# mean                     0.471876   33.240885    0.348958
# std                      0.331329   11.760232    0.476951
# min                      0.078000   21.000000    0.000000
# 25%                      0.243750   24.000000    0.000000
# 50%                      0.372500   29.000000    0.000000
# 75%                      0.626250   41.000000    1.000000
# max                      2.420000   81.000000    1.000000

# %%
sns.pairplot(dataset, hue='Class')
# Out:
# C:\Users\tonyd\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\tonyd\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.heatmap(dataset.corr(), annot=True)

# %%
# creating input features and target variables
X= dataset.iloc[:,0:8]
y= dataset.iloc[:,8]

# %%
X.head(2)
# Out:
#    Number  of times pregnant  Plasma glucose  Diastolic blood pressure  \
# 0                          6             148                        72
# 1                          1              85                        66
#
#    Triceps skinfold thickness  serum insulin  Body mass index  \
# 0                          35              0             33.6
# 1                          29              0             26.6
#
#    Diabetes pedigree function  Age
# 0                       0.627   50
# 1                       0.351   31

# %%
#standardizing the input feature
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# C:\Users\tonyd\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\tonyd\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from keras import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
#First Hidden Layer
classifier.add(Dense(4, activation='relu', kernel_initializer='random_normal', input_dim=8))
#Second  Hidden Layer
classifier.add(Dense(4, activation='relu', kernel_initializer='random_normal'))
#Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))

# %%
#Compiling the neural network
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy'])

# %%
#Fitting the data to the training dataset
classifier.fit(X_train,y_train, batch_size=10, epochs=50)
# Out:
# WARNING:tensorflow:From C:\Users\tonyd\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 537/537 [==============================] - 0s 930us/step - loss: 0.6904 - acc: 0.6425
# Epoch 2/50
# 537/537 [==============================] - 0s 74us/step - loss: 0.6812 - acc: 0.6555
# Epoch 3/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.6601 - acc: 0.6555
# Epoch 4/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.6180 - acc: 0.6629
# Epoch 5/50
# 537/537 [==============================] - 0s 78us/step - loss: 0.5681 - acc: 0.7058
# Epoch 6/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.5307 - acc: 0.7523
# Epoch 7/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.5074 - acc: 0.7691
# Epoch 8/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.4931 - acc: 0.7505
# Epoch 9/50
# 537/537 [==============================] - 0s 78us/step - loss: 0.4841 - acc: 0.7598
# Epoch 10/50
# 537/537 [==============================] - 0s 74us/step - loss: 0.4776 - acc: 0.7672
# Epoch 11/50
# 537/537 [==============================] - 0s 72us/step - loss: 0.4728 - acc: 0.7728
# Epoch 12/50
# 537/537 [==============================] - 0s 78us/step - loss: 0.4692 - acc: 0.7616
# Epoch 13/50
# 537/537 [==============================] - 0s 74us/step - loss: 0.4665 - acc: 0.7616
# Epoch 14/50
# 537/537 [==============================] - 0s 72us/step - loss: 0.4641 - acc: 0.7691
# Epoch 15/50
# 537/537 [==============================] - 0s 72us/step - loss: 0.4619 - acc: 0.7709
# Epoch 16/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.4601 - acc: 0.7821
# Epoch 17/50
# 537/537 [==============================] - 0s 82us/step - loss: 0.4590 - acc: 0.7821
# Epoch 18/50
# 537/537 [==============================] - 0s 85us/step - loss: 0.4576 - acc: 0.7821
# Epoch 19/50
# 537/537 [==============================] - 0s 72us/step - loss: 0.4566 - acc: 0.7858
# Epoch 20/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4551 - acc: 0.7840
# Epoch 21/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4543 - acc: 0.7858
# Epoch 22/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4531 - acc: 0.7840
# Epoch 23/50
# 537/537 [==============================] - 0s 71us/step - loss: 0.4524 - acc: 0.7858
# Epoch 24/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4515 - acc: 0.7877
# Epoch 25/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4508 - acc: 0.7877
# Epoch 26/50
# 537/537 [==============================] - 0s 65us/step - loss: 0.4501 - acc: 0.7858
# Epoch 27/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4496 - acc: 0.7877
# Epoch 28/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4491 - acc: 0.7877
# Epoch 29/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4490 - acc: 0.7840
# Epoch 30/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4479 - acc: 0.7803
# Epoch 31/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4472 - acc: 0.7858
# Epoch 32/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4470 - acc: 0.7877
# Epoch 33/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4463 - acc: 0.7877
# Epoch 34/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4460 - acc: 0.7877
# Epoch 35/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4451 - acc: 0.7840
# Epoch 36/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4454 - acc: 0.7821
# Epoch 37/50
# 537/537 [==============================] - 0s 71us/step - loss: 0.4445 - acc: 0.7877
# Epoch 38/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4444 - acc: 0.7840
# Epoch 39/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4445 - acc: 0.7877
# Epoch 40/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4439 - acc: 0.7858
# Epoch 41/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4433 - acc: 0.7896
# Epoch 42/50
# 537/537 [==============================] - 0s 67us/step - loss: 0.4425 - acc: 0.7858
# Epoch 43/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4422 - acc: 0.7877
# Epoch 44/50
# 537/537 [==============================] - 0s 71us/step - loss: 0.4422 - acc: 0.7858
# Epoch 45/50
# 537/537 [==============================] - 0s 71us/step - loss: 0.4415 - acc: 0.7896
# Epoch 46/50
# 537/537 [==============================] - 0s 71us/step - loss: 0.4414 - acc: 0.7840
# Epoch 47/50
# 537/537 [==============================] - 0s 72us/step - loss: 0.4407 - acc: 0.7877
# Epoch 48/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4407 - acc: 0.7858
# Epoch 49/50
# 537/537 [==============================] - 0s 76us/step - loss: 0.4396 - acc: 0.7896
# Epoch 50/50
# 537/537 [==============================] - 0s 69us/step - loss: 0.4404 - acc: 0.7840

# %%
eval_model=classifier.evaluate(X_train, y_train)
eval_model
# Out:
# 537/537 [==============================] - 0s 86us/step
# [0.43784924203901093, 0.7858473009237364]

# %%
y_pred=classifier.predict(X_test)
y_pred =(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[129  19]
#  [ 32  51]]
